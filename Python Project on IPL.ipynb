# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
ipl=pd.read_csv('ipl.csv')

# %%
ipl.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
ipl.shape
# Out:
# (816, 17)

# %%
ipl.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
ipl['venue'].value_counts()
# Out:
# Eden Gardens                                            77
# Feroz Shah Kotla                                        74
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Rajiv Gandhi International Stadium, Uppal               64
# MA Chidambaram Stadium, Chepauk                         57
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Dubai International Cricket Stadium                     33
# Sheikh Zayed Stadium                                    29
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Maharashtra Cricket Association Stadium                 21
# Sharjah Cricket Stadium                                 18
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# M.Chinnaswamy Stadium                                   15
# ...

# %%
ipl['player_of_match'].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# S Anirudha         1
# M Kartik           1
# R McLaren          1
# RJ Harris          1
# PJ Cummins         1
# Name: player_of_match, Length: 233, dtype: int64

# %%
#Top 10 players who becomes Player of Match
ipl['player_of_match'].value_counts()[0:10]
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# SK Raina          14
# V Kohli           13
# G Gambhir         13
# Name: player_of_match, dtype: int64

# %%
#Bar Plotting
#Player of Match (Top 10 player)
plt.figure(figsize=(15,5))
plt.bar(list(ipl['player_of_match'].value_counts()[0:10].keys()),list(ipl['player_of_match'].value_counts()[0:10]),color='orange')
plt.show()

# %%
#Venue (Top 10 Venues)
plt.figure(figsize=(30,10))
plt.bar(list(ipl['venue'].value_counts()[0:10].keys()),list(ipl['venue'].value_counts()[0:10]),color=['green'])
plt.show()

# %%
ipl.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
#Extracting the data, which shows first batting
first_bat=ipl[ipl['toss_decision']!='field']
first_bat.head()
# Out:
#        id        city        date player_of_match  \
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
# 5  335987      Jaipur  2008-04-21       SR Watson
#
#                                         venue  neutral_venue  \
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# 5                      Sawai Mansingh Stadium              0
#
#                    team1                        team2          toss_winner  \
# 1        Kings XI Punjab          Chennai Super Kings  Chennai Super Kings
# 2       Delhi Daredevils             Rajasthan Royals     Rajasthan Royals
# ...

# %%
win_by_bat=first_bat[first_bat['result']!='wickets']
win_by_bat.head()
# Out:
#         id        city        date player_of_match  \
# 1   335983  Chandigarh  2008-04-19      MEK Hussey
# 14  335996   Bangalore  2008-04-28        MS Dhoni
# 18  336000      Jaipur  2008-05-01     SA Asnodkar
# 21  336003  Chandigarh  2008-05-03       IK Pathan
# 28  336010     Kolkata  2008-05-08      SC Ganguly
#
#                                          venue  neutral_venue  \
# 1   Punjab Cricket Association Stadium, Mohali              0
# 14                       M Chinnaswamy Stadium              0
# 18                      Sawai Mansingh Stadium              0
# 21  Punjab Cricket Association Stadium, Mohali              0
# 28                                Eden Gardens              0
#
#                           team1                        team2  \
# 1               Kings XI Punjab          Chennai Super Kings
# 14  Royal Challengers Bangalore          Chennai Super Kings
# 18             Rajasthan Royals        Kolkata Knight Riders
# ...

# %%
#Plotting histogram by using 'runs' data from'result'
plt.figure(figsize=(10,5))
plt.hist(win_by_runs['result_margin'],color='red')
plt.title("Win by Runs vs Matches")
plt.show()

# %%
#here we can see that number od matches won by upto 20 runs is more than mathes won by 40,60,80,100,120 & 140 runs

# %%
first_bat['winner'].value_counts()

# %%
first_bat.head()

# %%
#Top 10 Teams, who choose to bat first and win the match
#Bar Plot
plt.figure(figsize=(20,5))
plt.bar(list(first_bat['winner'].value_counts()[0:10].keys()),list(first_bat['winner'].value_counts()[0:10]),color='blue')
plt.show()

# %%
#Pie Plot in percentage (%)
plt.figure(figsize=(20,20))
plt.pie(list(first_bat['winner'].value_counts()[0:10]),labels=list(first_bat['winner'].value_counts()[0:10].keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl.head()

# %%
#Extracting data, which shows first fielding
field_first=ipl[ipl['toss_decision']!='bat']
field_first.head()

# %%
field_first['winner'].value_counts()

# %%
win_by_wicket=field_first[field_first['result']!='runs']
win_by_wicket.head()

# %%
#Plotting histogram by using 'wickets' data from'result'
plt.figure(figsize=(10,10))
plt.hist(win_by_wicket['result_margin'],color='red')
plt.title("Wickets vs Matches")
plt.show()

# %%
#here we can see that number od matches won by 6 wickets is more than mathes won by other numbers of wickets

# %%
field_first['winner'].value_counts()

# %%
#Top 10 Teams, who choose to field first and win the match
#Bar Plot
plt.figure(figsize=(20,5))
plt.bar(list(field_first['winner'].value_counts()[0:10].keys()),list(field_first['winner'].value_counts()[0:10]),color='blue')
plt.show()

# %%
#Pie Plot in percentage (%)
plt.figure(figsize=(20,20))
plt.pie(list(field_first['winner'].value_counts()[0:10]),labels=list(field_first['winner'].value_counts()[0:10].keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl.head()

# %%
ipl.shape

# %%
ipl['city'].value_counts()

# %%
#Number of matches, where a team won the toss and won the match also
import numpy as np
np.sum(ipl['toss_winner']==ipl['winner'])

# %%
(418/816)

# %%
#there are 51.224% of matches in which a particular team won the toss and also won the match

# %%
ipl.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
#finding out all match id
ipl['id'].unique()
# Out:
# array([ 335982,  335983,  335984,  335985,  335986,  335987,  335988,
#         335989,  335990,  335991,  335992,  335993,  335994,  335995,
#         335996,  335997,  335998,  335999,  336000,  336001,  336002,
#         336003,  336004,  336005,  336006,  336007,  336008,  336009,
#         336010,  336011,  336012,  336013,  336014,  336015,  336016,
#         336017,  336018,  336019,  336020,  336021,  336022,  336023,
#         336024,  336025,  336026,  336027,  336028,  336029,  336031,
#         336032,  336033,  336034,  336035,  336036,  336037,  336038,
#         336039,  336040,  392181,  392182,  392183,  392184,  392185,
#         392186,  392188,  392189,  392190,  392191,  392192,  392194,
#         392195,  392196,  392197,  392198,  392199,  392200,  392201,
#         392202,  392203,  392204,  392205,  392206,  392207,  392208,
#         392209,  392210,  392211,  392212,  392213,  392214,  392215,
# ...
